# %%
import pandas as pd
df = pd.read_csv("films.csv")

df.head()
# Out:
#    rang                                 titre                      titre_vo  \
# 0     1             Bienvenue chez les Ch'tis                 Réalisé par :
# 1     2       Les Bronzés 3: Amis pour la vie                 Réalisé par :
# 2     3      Star Wars: Le Réveil de la Force  Star Wars: The Force Awakens
# 3     4  Astérix et Obélix: Mission Cléopatre                 Réalisé par :
# 4     5                                Taxi 2                 Réalisé par :
#
#   realisateur                                 genre  annee pays  entrees  \
# 0     Comédie             Bienvenue chez les Ch'tis   2008  f25  4378720
# 1     Comédie       Les Bronzés 3: Amis pour la vie   2006  f25  3906694
# 2     Fantasy      Star Wars: Le Réveil de la Force   2015  f23  3801235
# 3     Comédie  Astérix et Obélix: Mission Cléopatre   2002  f25  3685097
# 4     Comédie                                Taxi 2   2000  f25  3478850
#
#    salles  moy_salle part_marche  \
# ...
