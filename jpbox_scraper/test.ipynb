# %%
import pandas as pd
df = pd.read_csv("films.csv")

df.tail(30)
# Out:
#     film_id  realisateur_id  rang  \
# 0      2077           432.0    16
# 1     18826           174.0    17
# 2     17528           505.0     8
# 3     10042           947.0     1
# 4      2398           438.0     5
# 5       320           282.0     2
# 6     13345           575.0     3
# 7       701           147.0     7
# 8        12           885.0    13
# 9     10845           333.0     9
# 10    21065          1016.0    14
# 11     3039           201.0    22
# 12        3             NaN    12
# 13     1400           281.0    15
# 14      700           445.0    11
# 15     1741           777.0     4
# 16    10193           885.0    10
# 17     9975           174.0    23
# 18     2704           102.0    19
# 19     1742            89.0    18
# 20       28           154.0    20
# 21      321           154.0    21
# 22    11191           947.0    24
# 23    15113           962.0    27
# 24    17666           947.0    30
# 25     1045           441.0    28
# ...
