# %%
import pandas as pd
df = pd.read_csv("films.csv")

df.tail(30)
# Out:
#     film_id  realisateur_id  rang  \
# 0       701           147.0     7
# 1     13345           575.0     3
# 2     17528           505.0     8
# 3      2398           438.0     5
# 4     10845           333.0     9
# 5      2077           432.0    16
# 6     10042           947.0     1
# 7       320           282.0     2
# 8     18826           174.0    17
# 9        12           885.0    13
# 10    21065          1016.0    14
# 11     1400           281.0    15
# 12        3             NaN    12
# 13      700           445.0    11
# 14     1742            89.0    18
# 15     3039           201.0    22
# 16     9975           174.0    23
# 17     2704           102.0    19
# 18    10193           885.0    10
# 19      321           154.0    21
# 20       28           154.0    20
# 21     1741           777.0     4
# 22    15113           962.0    27
# 23    11191           947.0    24
# 24     1045           441.0    28
# 25    17666           947.0    30
# ...

# %%
import pandas as pd
casting= pd.read_csv("casting_detail.csv")

casting.tail(30)
# Out:
#     film_id  person_id       nom_personne                 role  \
# 0         2        892       Kristen Wiig  Acteurs et actrices
# 1         2        594        Elie Semoun  Acteurs et actrices
# 2         2        658    - Queen Latifah  Acteurs et actrices
# 3         1        237        Liam Neeson  Acteurs et actrices
# 4         1         26      Michael Apted       Realisateur(s)
# 5         2        349     Vincent Cassel  Acteurs et actrices
# 6         1        608         Simon Pegg  Acteurs et actrices
# 7         2        146      Gérard Lanvin  Acteurs et actrices
# 8         3        142   Gérard Depardieu  Acteurs et actrices
# 9         3        756      René Goscinny  Acteurs et actrices
# 10        3        182     Jamel Debbouze  Acteurs et actrices
# 11        3        541      Franck Dubosc  Acteurs et actrices
# 12        3        189        José Garcia  Acteurs et actrices
# 13        3          5        Alain Delon  Acteurs et actrices
# ...
