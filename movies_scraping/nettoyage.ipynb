# %% [markdown]
# # nettoyage du dataset

# %%
import pandas as pd

# %%
df_movies = pd.read_csv("movies_filter_maj.csv")

# %%
df_movies.sample(2)
# Out:
#       index                                   title  \
# 1930   2046                                 Aladdin
# 4312   4952  OSS 117: Alerte rouge en Afrique noire
#
#                                                   image         date  \
# 1930  https://fr.web.img6.acsta.net/c_310_420/pictur...  22 mai 2019
# 4312  https://fr.web.img6.acsta.net/c_310_420/pictur...  4 août 2021
#
#      broadcast_place                        genres  certificate  \
# 1930        en salle  Aventure,Famille,Fantastique  Tout public
# 4312        en salle   Aventure,Comédie,Espionnage  Tout public
#
#                                                synopsis      directors  \
# 1930  Quand un charmant garçon des rues du nom d’Ala...    Guy Ritchie
# 4312  1981. Hubert Bonisseur de La Bath, alias OSS 1...  Nicolas Bedos
#
#                    scenarists                                    actors  \
# 1930  John August,Guy Ritchie  Will Smith,Anthony Kavanagh,Mena Massoud
# ...

# %%
df_movies['genres'].describe()
# Out:
# count      4879
# unique      396
# top       Drame
# freq       1132
# Name: genres, dtype: object

# %%
df_movies.shape
# Out:
# (4879, 20)

# %%
df_movies['title'] = df_movies['title'].str.lower()

# %%
df_movies.sample(2)
# Out:
#       index                title  \
# 3436   3789                pearl
# 2428   2577  la troisième guerre
#
#                                                   image               date  \
# 3436  https://fr.web.img3.acsta.net/c_310_420/pictur...    30 janvier 2019
# 2428  https://fr.web.img3.acsta.net/c_310_420/pictur...  22 septembre 2021
#
#      broadcast_place genres  certificate  \
# 3436        en salle  Drame  Tout public
# 2428        en salle  Drame  Tout public
#
#                                                synopsis      directors  \
# 3436  Léa Pearl s’apprête à concourir pour le presti...     Elsa Amiel
# 2428  Léo vient juste de terminer ses classes et pou...  Giovanni Aloi
#
#                            scenarists  \
# 3436                       Elsa Amiel
# 2428  Giovanni Aloi,Dominique Baumard
#
#                                        actors average_notes_press  \
# 3436     Julia Föry,Peter Mullan,Vidal Arzoni                 3,3
# ...

# %%
df_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4879 entries, 0 to 4878
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   index                     4879 non-null   int64
#  1   title                     4879 non-null   object
#  2   image                     4879 non-null   object
#  3   date                      4879 non-null   object
#  4   broadcast_place           4879 non-null   object
#  5   genres                    4879 non-null   object
#  6   certificate               4879 non-null   object
#  7   synopsis                  4879 non-null   object
#  8   directors                 4879 non-null   object
#  9   scenarists                4879 non-null   object
#  10  actors                    4858 non-null   object
#  11  average_notes_press       4879 non-null   object
#  12  average_notes_spectators  4879 non-null   object
# ...

# %%
df_movies['average_notes_press'] = df_movies['average_notes_press'].str.replace(",", ".")

# %%
df_movies['average_notes_press']
# Out:
# 0       4.6
# 1       2.8
# 2       3.9
# 3       3.7
# 4       3.0
#        ...
# 4874    3.6
# 4875    3.5
# 4876    3.1
# 4877    2.9
# 4878    3.7
# Name: average_notes_press, Length: 4879, dtype: object

# %%
df_movies['average_notes_press'] = df_movies['average_notes_press'].astype('float')

# %%
df_movies['average_notes_spectators'] = df_movies['average_notes_spectators'].str.replace(",", ".")
df_movies['average_notes_spectators']
# Out:
# 0       4.1
# 1       1.9
# 2       4.1
# 3       3.8
# 4       3.1
#        ...
# 4874    2.8
# 4875    2.1
# 4876    2.4
# 4877    2.3
# 4878    3.4
# Name: average_notes_spectators, Length: 4879, dtype: object

# %%
df_movies['average_notes_spectators'] = df_movies['average_notes_spectators'].astype('float')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df_movies['average_notes_spectators'] = df_movies['average_notes_spectators'].astype('float')
#
# File c:\Users\nicol\OneDrive\Bureau\simplon\20250401_popularity_movie_prediction\popularity_movie_prediction_project\.venv\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# ...
