# %% [markdown]
# # nettoyage du dataset

# %%
import pandas as pd

# %%
df_movies = pd.read_csv("movies_filter_maj.csv")

# %%
df_movies.sample(2)
# Out:
#       index                title  \
# 1446   1529  Elle est des nôtres
# 3236   3531    Les hommes libres
#
#                                                   image               date  \
# 1446  https://fr.web.img6.acsta.net/c_310_420/medias...  24 septembre 2003
# 3236  https://fr.web.img3.acsta.net/c_310_420/medias...  28 septembre 2011
#
#      broadcast_place        genres  certificate  \
# 1446        en salle         Drame  Tout public
# 3236        en salle  Drame,Guerre  Tout public
#
#                                                synopsis         directors  \
# 1446  Christine Blanc, secrétaire intérimaire, est u...     Siegrid Alnoy
# 3236  1942, Paris est occupée par les Allemands. You...  Ismael Ferroukhi
#
#                                scenarists  \
# 1446        Siegrid Alnoy,Jérôme Beaujour
# 3236  Ismael Ferroukhi,Alain-Michel Blanc
#
#                                            actors average_notes_press  \
# ...

# %%
df_movies['genres'].describe()
# Out:
# count      4879
# unique      396
# top       Drame
# freq       1132
# Name: genres, dtype: object
